# %%
# Code 01
print("Hola Mundo desde Notebook!")
# Out:
# Hola Mundo desde Notebook!

# %% [markdown]
# # Sesión 04
# - Mi primer notebook
# - Imprimir árbol
# - Crer Markdown
# - Subir a mi repositorio de GitHub
# - Dibujar un emoji 😊 (windows + .)
